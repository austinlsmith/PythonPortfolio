# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('Desktop/Python/vgsales-12-4-2019.csv')

# %%
data.head()
# Out:
#    Rank                           Name                      basename  \
# 0     1                     Wii Sports                    wii-sports
# 1     2              Super Mario Bros.              super-mario-bros
# 2     3                 Mario Kart Wii                mario-kart-wii
# 3     4  PlayerUnknown's Battlegrounds  playerunknowns-battlegrounds
# 4     5              Wii Sports Resort             wii-sports-resort
#
#       Genre ESRB_Rating Platform         Publisher         Developer  \
# 0    Sports           E      Wii          Nintendo      Nintendo EAD
# 1  Platform         NaN      NES          Nintendo      Nintendo EAD
# 2    Racing           E      Wii          Nintendo      Nintendo EAD
# 3   Shooter         NaN       PC  PUBG Corporation  PUBG Corporation
# 4    Sports           E      Wii          Nintendo      Nintendo EAD
#
#    VGChartz_Score  Critic_Score  ...  NA_Sales  PAL_Sales  JP_Sales  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55792 entries, 0 to 55791
# Data columns (total 23 columns):
# Rank              55792 non-null int64
# Name              55792 non-null object
# basename          55792 non-null object
# Genre             55792 non-null object
# ESRB_Rating       23623 non-null object
# Platform          55792 non-null object
# Publisher         55792 non-null object
# Developer         55775 non-null object
# VGChartz_Score    0 non-null float64
# Critic_Score      6536 non-null float64
# User_Score        335 non-null float64
# Total_Shipped     1827 non-null float64
# Global_Sales      19415 non-null float64
# NA_Sales          12964 non-null float64
# PAL_Sales         13189 non-null float64
# JP_Sales          7043 non-null float64
# Other_Sales       15522 non-null float64
# Year              54813 non-null float64
# Last_Update       9186 non-null object
# url               55792 non-null object
# status            55792 non-null int64
# ...

# %%
data.isnull().count()
# Out:
# Rank              55792
# Name              55792
# basename          55792
# Genre             55792
# ESRB_Rating       55792
# Platform          55792
# Publisher         55792
# Developer         55792
# VGChartz_Score    55792
# Critic_Score      55792
# User_Score        55792
# Total_Shipped     55792
# Global_Sales      55792
# NA_Sales          55792
# PAL_Sales         55792
# JP_Sales          55792
# Other_Sales       55792
# Year              55792
# Last_Update       55792
# url               55792
# status            55792
# Vgchartzscore     55792
# img_url           55792
# dtype: int64

# %%
#plot graphy sales by year 
plt.figure(figsize=(10,10))
plt.xticks(rotation=45)
sns.countplot(data.Year)

# %%
plt.figure(figsize=(10,10))
plt.xticks(rotation=45)
sns.countplot(data.Platform)

# %%
top_20_platforms = data['Platform'].value_counts()[:20]

# %%
XOne = data[data.Platform == 'XOne']
XOne
# Out:
#         Rank                                    Name  \
# 107      108                      Grand Theft Auto V
# 134      135               Call of Duty: Black Ops 3
# 172      173                      Call of Duty: WWII
# 188      189                   Red Dead Redemption 2
# 211      212                               Minecraft
# 229      230          Call of Duty: Advanced Warfare
# 238      239                           Battlefield 1
# 250      251                               Fallout 4
# 258      259                       Halo 5: Guardians
# 271      272            Call of Duty: Black Ops IIII
# 275      276          Call of Duty: Infinite Warfare
# 348      349            Star Wars Battlefront (2015)
# 407      408                                 FIFA 17
# 424      425          Gears of War: Ultimate Edition
# 431      432                 Assassin's Creed: Unity
# 464      465       Halo: The Master Chief Collection
# 470      471                                 Destiny
# ...

# %%
XOne_ratings = XOne['ESRB_Rating'].value_counts()
XOne_ratings
# Out:
# M      189
# T      146
# E      127
# E10    107
# RP      19
# Name: ESRB_Rating, dtype: int64

# %%
X360 = data[data.Platform == 'X360']

# %%
X360_ratings = X360['ESRB_Rating'].value_counts()
X360_ratings
# Out:
# T      387
# M      338
# E      291
# E10    206
# RP      36
# EC       1
# Name: ESRB_Rating, dtype: int64

# %%
Platform_group = data.groupby('Platform').Global_Sales.sum()
excel_table = pd.pivot_table(data[data.Platform.isin(Platform_group.sort_values(ascending=False)[:20].index)],values=['Global_Sales'],index=['Year'],columns=['Platform'],aggfunc='sum',margins=False)
excel_table
# Out:
#          Global_Sales                                                          \
# Platform         2600    3DS      DS    GBA     GC    N64   NES     NS     PC
# Year
# 1970.0           0.21    NaN    0.00   0.00    NaN    NaN   NaN    NaN   0.46
# 1973.0            NaN    NaN     NaN    NaN    NaN    NaN   NaN    NaN   0.00
# 1975.0            NaN    NaN    0.00    NaN    NaN    NaN   NaN    NaN    NaN
# 1977.0           2.50    NaN     NaN    NaN    NaN    NaN   NaN    NaN   0.00
# 1978.0           6.19    NaN     NaN    NaN    NaN    NaN   NaN    NaN    NaN
# 1979.0           0.31    NaN     NaN    NaN    NaN    NaN   NaN    NaN   0.00
# 1980.0           2.58    NaN     NaN    NaN    NaN    NaN   NaN    NaN   0.00
# 1981.0          10.49    NaN     NaN    NaN    NaN    NaN   NaN    NaN   0.00
# 1982.0          35.69    NaN     NaN    NaN    NaN    NaN   NaN   0.00   0.00
# 1983.0          22.68   0.00    0.00    NaN    NaN    NaN  0.00   0.00   0.00
# ...

# %%
plt.figure(figsize=(19,15))
sns.heatmap(excel_table['Global_Sales'],linewidths=.5,annot=True,vmin=0.01,cmap='coolwarm')

# %%
Genre_group = data.groupby('Genre').Global_Sales.sum()
excel_table_genre = pd.pivot_table(data[data.Genre.isin(Genre_group.sort_values(ascending=False)[:20].index)],values=['Global_Sales'],index=['Year'],columns=['Platform'],aggfunc='sum',margins=False)
excel_table_genre
# Out:
#          Global_Sales                                                  ...  \
# Platform         2600   3DO    3DS 5200 7800 ACPC   AJ  AST  Aco Amig  ...
# Year                                                                   ...
# 1970.0           0.21   NaN    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 1973.0            NaN   NaN    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 1975.0            NaN   NaN    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 1977.0           2.50   NaN    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 1978.0           6.19   NaN    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 1979.0           0.31   NaN    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 1980.0           2.58   NaN    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 1981.0          10.49   NaN    NaN  0.0  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 1982.0          35.69   NaN    NaN  0.0  NaN  NaN  NaN  NaN  NaN  NaN  ...
# ...

# %%
plt.figure(figsize=(19,15))
sns.heatmap(excel_table_genre['Global_Sales'],linewidths=.5,annot=True,vmin=0.01,cmap='coolwarm')
